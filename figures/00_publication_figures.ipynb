# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.figures_utils import *

# %%
load_sample("SRR26107673")
# Out:
#          CpG_chrm  CpG_start   CpG_end  methylated_reads  coverage
# 0            chr1      10468     10470                 0         0
# 1            chr1      10470     10472                 0         0
# 2            chr1      10483     10485                 0         0
# 3            chr1      10488     10490                 0         0
# 4            chr1      10492     10494                 0         0
# ...           ...        ...       ...               ...       ...
# 28217004     chrY   59362432  59362434                 0         0
# 28217005     chrY   59362484  59362486                 0         0
# 28217006     chrY   59362487  59362489                 0         0
# 28217007     chrY   59362492  59362494                 0         0
# 28217008     chrY   59362590  59362592                 0         0
#
# [28217009 rows x 5 columns]

# %%
load_pmds("SRR26107673", "dnmtools")
# Out:
#      chrom      start        end
# 0     chr1    2682000    2990996
# 1     chr1    3995533    5918153
# 2     chr1    6991646    7276639
# 3     chr1   11388270   11716115
# 4     chr1   12673314   13051724
# ...    ...        ...        ...
# 1355  chrX  148710096  148908000
# 1356  chrX  150248678  150568936
# 1357  chrX  150628504  151058149
# 1358  chrX  151404027  152002900
# 1359  chrX  152463340  152602870
#
# [1360 rows x 3 columns]

# %%
get_region_context_df()
# Out:
#                                sample_id         tool platform region_type  \
# 0                             ESO26.wgbs  methylseekr     wgbs         PMD
# 1                             ESO26.wgbs  methylseekr     wgbs         PMD
# 2                             ESO26.wgbs  methylseekr     wgbs         PMD
# 3                             ESO26.wgbs  methylseekr     wgbs         PMD
# 4                             ESO26.wgbs  methylseekr     wgbs         PMD
# ...                                  ...          ...      ...         ...
# 1287189  WGBS_colon-primary-tumor_3_meth      mmseekr     wgbs         PMD
# 1287190  WGBS_colon-primary-tumor_3_meth      mmseekr     wgbs         PMD
# 1287191  WGBS_colon-primary-tumor_3_meth      mmseekr     wgbs         PMD
# 1287192  WGBS_colon-primary-tumor_3_meth      mmseekr     wgbs         PMD
# 1287193  WGBS_colon-primary-tumor_3_meth      mmseekr     wgbs         PMD
#
# ...
