# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils.methyl_tool_comparator import MethylToolComparator, MethylToolAggregateComparator

# %%
comparator = MethylToolComparator("test_comparator_config.yaml", "test_out")

# %%
comparator.run()
# Out:
# [2026-06-25 13:54:26] Building shared prep artifacts in test_out/comparison/WGBS_colon-primary-normal_1_meth/shared_prep
# [2026-06-25 13:54:33] Command gunzip -c /uufs/chpc.utah.edu/common/home/u0914269/clement/projects/20260624_methylseg/data/methylation_data/WGBS_colon-primary-normal_1_meth.bed.gz | Output: /uufs/chpc.utah.edu/common/home/clementm-group1/projects/20260624_methylseg/analysis/01_region_calling_analysis/test_out/comparison/WGBS_colon-primary-normal_1_meth/shared_prep/..wgbs.tsv.tmp.975746.1782417266918254939.unsorted.tmp.975746.1782417266918376839 | Error: test_out/comparison/WGBS_colon-primary-normal_1_meth/logs/job_logs/gunzip_4838675.stderr | time=6.66s | peak_mem=1.6 MB
# ...

# %%
aggregator = MethylToolAggregateComparator(
    comparison_out_dirs=[comparator.out_dir, comparator.out_dir, comparator.out_dir]
)

# %%
aggregator.generate_aggregate_summary_plots()
# Out:
# {'all_region_stats.csv': 'test_out/comparison/aggregate_summaries/all_region_stats.csv',
#  'all_region_context_stats.csv': 'test_out/comparison/aggregate_summaries/all_region_context_stats.csv',
#  'all_run_stats.csv': 'test_out/comparison/aggregate_summaries/all_run_stats.csv',
#  'run_stat_summary.csv': 'test_out/comparison/aggregate_summaries/run_stat_summary.csv',
#  'region_stat_summary.csv': 'test_out/comparison/aggregate_summaries/region_stat_summary.csv',
#  'region_context_stat_summary.csv': 'test_out/comparison/aggregate_summaries/region_context_stat_summary.csv',
#  'run_runtime_sec_box.html': 'test_out/comparison/aggregate_summaries/run_runtime_sec_box.html',
#  'run_mem_peak_mb_box.html': 'test_out/comparison/aggregate_summaries/run_mem_peak_mb_box.html',
#  'region_n_regions_box.html': 'test_out/comparison/aggregate_summaries/region_n_regions_box.html',
#  'region_total_bp_box.html': 'test_out/comparison/aggregate_summaries/region_total_bp_box.html',
# ...
